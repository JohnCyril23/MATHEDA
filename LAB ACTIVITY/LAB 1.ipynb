# %% [markdown]
# JOHN CYRIL DUMAGUIN

# %% [markdown]
# Creating a list

# %%
numbers = [1, 2, 3, 4, 5]

# %% [markdown]
# Indexing

# %%
numbers = [1, 2, 3, 4, 5]
numbers[2]
# Out:
# 3

# %% [markdown]
# Modifying Elements

# %%
food=["pizza", "burger", "sushi", "pasta"]
food[0] = "fried chicken"
print(food)
# Out:
# ['fried chicken', 'burger', 'sushi', 'pasta']

# %% [markdown]
# Adding of Elements

# %%
numbers = [1, 2, 3, 4, 5]
numbers.append(6)
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
fruits = ["apple", "banana", "cherry"]
fruits.insert(1, "orange")
print(fruits)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %% [markdown]
# Removing Elements

# %%
foods = ['pizza', 'burger', 'sushi', 'pasta']
foods.remove('sushi')
numbers = [1, 2, 3, 4, 5]
numbers.remove(3)
print(foods)
print(numbers)
# Out:
# ['pizza', 'burger', 'pasta']
# [1, 2, 4, 5]

# %% [markdown]
# Sort and Sorted
