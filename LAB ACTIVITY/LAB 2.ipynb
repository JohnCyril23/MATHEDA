# %%
JOHN CYRIL DUMAGUIN

# %% [markdown]
# FOR LOOP

# %%
foods = ["cake", "ice cream", "cookies", "carbonara"]
for foods in foods:
    print(f'I like eating {foods}')
# Out:
# I like eating cake
# I like eating ice cream
# I like eating cookies
# I like eating carbonara

# %%
for i in range (8):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# Iliterating over a Dictionary

# %%
user={"name":"John","age":21,"city":"Talisay"}
for key in user:
    print(key) 
    
for val in user.values():
    print(val)
# Out:
# name
# age
# city
# John
# 21
# Talisay
